# %%
import duckdb
import gzip
import os


def peek_gz_with_duckdb(file_path, num_lines=5):
    """
    Peeks at the first few lines of a .gz file using DuckDB.

    Args:
        file_path (str): The path to the .gz file.
        num_lines (int): The number of lines to peek at (default is 5).
    """
    try:
        with gzip.open(file_path, "rt") as f:
            # Read the first few lines manually
            peek_data = [next(f) for _ in range(num_lines)]
            print("First few lines (manual read):")
            for line in peek_data:
                print(line.strip())

        # Use DuckDB to query the first few lines (demonstration)
        con = duckdb.connect(database=":memory:", read_only=True)
        query = f"""
            SELECT *
            FROM read_csv_auto('{file_path}', compression='gzip')
            LIMIT {num_lines};
        """
        result = con.execute(query).fetchall()
        con.close()

        print(f"\nFirst {num_lines} lines (DuckDB query):")
        for row in result:
            print(row)

    except FileNotFoundError:
        print(f"Error: File not found at '{file_path}'")
    except gzip.BadGzipFile:
        print(f"Error: '{file_path}' does not appear to be a valid gzip file.")
    except StopIteration:
        print(f"Note: The file '{file_path}' has fewer than {num_lines} lines.")
    except Exception as e:
        print(f"An error occurred: {e}")


if __name__ == "__main__":
    # Example usage: Create a sample .gz file

    peek_gz_with_duckdb(
        "/Users/christophersteinberg/Documents/GitHub/downthestreet/data/urls-meta-23-11-02.csv.gz",
        num_lines=3,
    )

    # Clean up the sample file

# %%
import duckdb
import pandas as pd

def peak_parquet(file_path, num_rows=200):
    """
    Peaks at the contents of a Parquet file using DuckDB.

    Args:
        file_path (str): The path to the Parquet file.
        num_rows (int, optional): The number of rows to display. Defaults to 5.

    Returns:
        pandas.DataFrame: A Pandas DataFrame containing the first 'num_rows' of the file,
                          or None if the file cannot be read.
    """
    try:
        con = duckdb.connect(database=':memory:', read_only=False)
        query = f"SELECT * FROM '{file_path}' LIMIT {num_rows}"
        result = con.execute(query).fetchdf()

        length = f"SELECT COUNT(*) FROM '{file_path}'"
        total_length = con.execute(length).fetchdf()
        print(total_length)
        con.close()

        if not result.empty:
            print(f"Peeking at the first {num_rows} rows of '{file_path}':")
            print(result.to_string())
            return result
        else:
            print(f"The Parquet file '{file_path}' is empty.")
            return None

    except Exception as e:
        print(f"Error peeking at '{file_path}': {e}")
        return None

if __name__ == '__main__':
    peak_parquet("../data/about_pages.parquet")
# Out:
#    count_star()
# 0         12259
# Peeking at the first 200 rows of '../data/about_pages.parquet':
#                                                                                                                url
# 0                                                                                 https://philosophy.gmu.edu/about
# 1                                                            https://www.wbur.org/podcasts/anythingforselena/about
# 2                                                                                      https://www.twice.com/about
# 3                                                                                       https://www.tedleo.com/bio
# 4                                                    https://stmarksutah.org/homilyarchive/2022/06/02/presentation
# 5                                                                         https://www.ozarkactorstheatre.org/about
# 6                                                                               https://www.linuxbabe.com/about-me
# 7                                                                          https://jamesklise.com/about-the-author
# 8                                                                                     https://bronxriver.org/about
# 9                                                                                       http://www.nsm88.org/about
# 10                                                                           https://foodtruckpromotions.com/about
# 11                                                                              https://www.adhdmarriage.com/about
# 12                                                                    https://www.newsdemon.com/newsgroup-info/bio
# 13                                                   https://tomnicholasgallery.com/artists/tom-nicholas/biography
# 14                                                                                        https://slsp.ch/en/about
# 15                                                                              https://www.onyeonyemaechi.com/bio
# 16                                                                             https://www.world-housing.net/about
# 17                                                                    https://abms.kmu.edu.pk/index.php/abms/about
# 18                                                                 https://www.aism.edu.my/our-campus/introduction
# 19                                      https://glamportal.auctr.edu/exhibits/show/color-is-rationale/introduction
# 20                                                                                https://uwbdr.uwb.edu/odei/about
# 21                                                                              https://www.lipscomb.edu/ljs/about
# 22                                                                                      https://www.cjcj.org/about
# 23                                                                             https://woodmereartmuseum.org/about
# 24                                                                             https://icarusfilms.com/other/about
# 25                                                                                http://galleryongreene.com/about
# 26                                                                                 https://www.isofusion.com/about
# 27                                                                               https://www.stfaiths.org.za/about
# 28                                                                        https://www.scienceinpublic.com.au/about
# 29                                                                     https://www.smgeelong.catholic.edu.au/about
# 30                                                                          https://wearetheinterrupters.com/about
# 31                                                                                      https://www.wrur.org/about
# 32                                                                https://www.the-trench.org/consultancy/biography
# 33                                                                                      https://jmarbach.com/about
# 34                                                                            https://www.lookoutamerica.org/about
# 35                                                                                https://www.borshevsky.com/about
# 36                                                                                  https://www.doniphan.org/about
# 37                                                               https://goethe-lexicon.pitt.edu/GL/orcidapi/about
# 38                                                                           https://www.ijcce.ac.ir/journal/about
# 39                                                                            https://www.gilesthomas.com/personal
# 40                                                                                 http://www.dennisbeach.tv/about
# 41                                                                                http://www.tablapusher.com/about
# 42                                                                                  https://www.oldbaldy.org/about
# 43                                                          https://www.foodsystemsjournal.org/index.php/fsj/about
# 44                                                          https://fastplants.org/resources/digital_library/about
# 45                                                                                   https://www.runotmill.com/bio
# 46                                                                             https://www.eduardomorais.com/about
# 47                                                                    https://inventionworks.engr.utexas.edu/about
# 48                                                                  https://www.green-history.uk/home/introduction
# 49                                                                      https://www.performingstatistics.org/about
# 50                                                               https://www.thefabricator.com/thefabricator/about
# 51                                                                                      https://purves.co.uk/about
# 52                                                                     https://www.gunnisonpioneermuseum.com/about
# 53                                                                                http://www.lunaimaging.com/about
# 54                                                                                   https://cleliaadams.com/about
# 55                                                                    https://www.educationwithoutborders.ca/about
# 56                                                                               https://pierredegaillande.com/bio
# 57             https://www.ulster.ac.uk/faculties/ulster-university-business-school/financial-innovation-lab/about
# 58   https://www.ulster.ac.uk/faculties/ulster-university-business-school/hospitality-and-tourism-management/about
# 59                                                                     https://www.ulster.ac.uk/mindyourmood/about
# 60       https://www.ulster.ac.uk/research/topic/computer-science/information-and-communications-engineering/about
# 61                                                                              https://www.buildabridge.org/about
# 62                                                                          https://www.anthonymccrossan.com/about
# 63                                                                          https://www.greatplacetowork.com/about
# 64                                                                               https://www.murrayclose.com/about
# 65                                                                           https://www.gastonrenard.com.au/about
# 66                                                                                    https://www.noprcd.org/about
# 67                                                                   https://www.w3schools.in/angular/introduction
# 68                                                                                 http://www.kevinkling.com/about
# 69                                                                                      https://www.ggmi.nyc/about
# 70                                                                        https://www.peterreynoldsbooks.com/about
# 71                                                          https://mjs.uomustansiriyah.edu.iq/index.php/MJS/about
# 72                                                                            https://www.marianschwartz.com/about
# 73                                                                       http://www.fundraisingmagic.com/biography
# 74                                                                                     https://laurarain.net/about
# 75                                                                   https://blog.thermwood.com/topic/introduction
# 76                                                                             https://www.laurielclewis.com/about
# 77                                                                http://www.sausalito-online.com/tag/presentation
# 78                                                                                https://www.paulinereese.com/bio
# 79                                                                                 https://worldpositive.com/about
# 80                                                                                https://www.theiridium.com/about
# 81                                                                            https://rubygarage.org/company/about
# 82                                                                              https://www.johngodoy.com/about-me
# 83                                                                                   https://www.algoodwin.com/bio
# 84                                                            https://www.spiritofspeyside.com/whisky-school/about
# 85                                             https://www.gallerieswest.ca/galleries-west-magazine/about-us/about
# 86                                                                                      https://dsi.mtsu.edu/about
# 87                                                                               https://www.gaelicstorm.com/about
# 88                                                                          https://www.inpursuitofvenus.com/about
# 89                                                                                   https://godsticks.co.uk/about
# 90                                                                               https://www.cholianglin.com/about
# 91                          https://rebelarchives.humspace.ucla.edu/exhibits/show/sisters-in-struggle/introduction
# 92                                                                                  https://lyz.substack.com/about
# 93                                                      https://www.frommers.com/destinations/austria/introduction
# 94                                                                              https://www.mkjmarketing.com/about
# 95                                                                        https://www.sydneydeckbuild.com.au/about
# 96                                                                            https://www.venturaaudubon.org/about
# 97                                                                                 https://www.jonkaiser.com/about
# 98                                                                         http://www.reform-ireland.org/tag/about
# 99                                                                                 http://www.chuckprophet.com/bio
# 100                                                                             https://trafficrider.org/tag/about
# 101                                                                                       https://chicory.co/about
# 102                                                             https://ecfr.eu/scorecard/2015/extras/introduction
# 103                                                                             https://ecfr.eu/special/tsst/about
# 104                                                                                      https://nocafos.org/about
# 105                                                                          https://www.mcraeartstudios.com/about
# 106                                                                                    https://piecepack.net/about
# 107                                                                                 https://chicantiques.com/about
# 108                                                                 http://www.livingwithdragons.com/2007/10/about
# 109                                                                   http://www.blindcleaners.biz/index.php/about
# 110                                                                https://www.ejh.it/index.php/ejh/orcidapi/about
# 111                                                                                  https://sectorsource.ca/about
# 112                                                                        https://www.heartdancerecords.com/about
# 113                                                                              http://www.charliedaniels.com/bio
# 114                                                                               https://www.chesapeake.edu/about
# 115                                                                             https://www.transathlete.com/about
# 116                                                                               https://liveforaliving.com/about
# 117                                                                                 https://womanonrails.com/about
# 118                                                        https://www.brillianceremovalistsmelbourne.com.au/about
# 119                                                                               https://www.drdispatch.com/about
# 120                                                                     https://www.hospiceofchattanooga.org/about
# 121                                                                                    https://pptc.org/blog/about
# 122                                                                              https://thescipub.com/ajavs/about
# 123                                                                              https://thescipub.com/ajeas/about
# 124                                                            https://www.morganmclintic.com/pr/category/personal
# 125                                                                            https://adlrocha.substack.com/about
# 126                                                                              https://www.ordinariate.net/about
# 127                                                                   https://maadmob.com.au/category/presentation
# 128                                                                               https://www.liquidtext.net/about
# 129                                                               http://tinybooks.org/journal/2016/11/19/about-me
# 130                                                                    https://amazingarchitecture.com/pages/about
# 131                                                                               http://www.culturemill.org/about
# 132                                                                    https://www.legallyunconventional.com/about
# 133                                                                              https://www.harlemstage.org/about
# 134                                                                                    https://alyssasec.com/about
# 135                                                                                   https://www.lck2.co.uk/about
# 136                                                                               http://www.hornlessons.org/about
# 137                                                                      https://signalproblems.substack.com/about
# 138                                                                        https://www.nicolabenedetti.co.uk/about
# 139                                                                               http://www.timothybeal.com/about
# 140                                                             http://www.triquarterly.org/issues/issue-154/about
# 141                                                                          https://www.tfana.org/education/about
# 142                                                                   https://pw.lacounty.gov/swe/DevilsGate/about
# 143                                                                            https://www.maryhalvorson.com/about
# 144                                                                                https://www.andybiggs.com/about
# 145                                                                     https://www.waynelinseymusic.com/biography
# 146                                                                              https://www.shoutmeloud.com/about
# 147                                                                                  https://financebuzz.com/about
# 148                                                                               https://www.geosurv.com.au/about
# 149                                                                       https://www.ch-aviation.com/portal/about
# 150                                                                            https://www.andthenhesaid.com/about
# 151                                                                                https://whalebone-music.com/bio
# 152                                                                               http://www.lauradutton.com/about
# 153                                                                          http://reggaewave.net/index.php/about
# 154                                                                     https://www.charliebarnesmusic.co.uk/about
# 155                                                                                 https://www.damascus.com/about
# 156                                                                                      https://www.pme.com/about
# 157                                                                http://research.engineering.uiowa.edu/iip/about
# 158                                                                       https://pioneerworks.org/broadcast/about
# 159                                                                                   https://www.ebaman.com/about
# 160                                                                                     https://lizardfs.com/about
# 161                                                                         https://www.sallybeamish.com/biography
# 162                                                                                 https://www.explorit.org/about
# 163                                                                https://write.tedomum.net/spinlock/introduction
# 164                                                   https://www.geoplace.co.uk/street-naming-and-numbering/about
# 165                                                                                      https://bzamayo.com/about
# 166                                                                  http://www.alienfactory.co.uk/strutsgui/about
# 167                                                                       https://www.ippl.info/maker-studio/about
# 168                                                                            https://www.bessiesmithcc.org/about
# 169                                                                             https://www.thedoughboysnj.com/bio
# 170                                                                       https://www.thediamondcampaign.org/about
# 171                                                                              https://www.michaelpronko.com/bio
# 172                                                               http://blogcampaigning.com/blog/tag/introduction
# 173                                                                             https://www.lenkaclayton.com/hello
# 174                                                     https://www.uzhnu.edu.ua/en/cat/deps-center_coll_use/about
# 175                                                           https://www.uzhnu.edu.ua/en/cat/faculty-biolog/about
# 176                                                  https://www.uzhnu.edu.ua/en/cat/faculty-fhistory_relati/about
# 177                                                          https://www.uzhnu.edu.ua/en/cat/faculty-medical/about
# 178                                                                       https://www.centerstreetgrille.com/about
# 179                                                                        https://www.ubuntu-glasgow.org.uk/about
# 180                                                                                  https://www.grambart.ca/about
# 181                                                                           https://sustainableamerica.org/about
# 182                                 https://communityofgardens.si.edu/exhibits/show/interviewgardener/introduction
# 183                                                                             https://xine.sourceforge.net/about
# 184                                                                         https://www.howtostealachair.com/about
# 185                                                                                     https://cfac.byu.edu/about
# 186                                                                        https://www.esportsscotland.co.uk/about
# 187                                                                                    http://houston.pm.org/about
# 188                                                                             https://www.curanderismo.org/about
# 189                                                                                  https://www.kentuck.org/about
# 190                                            https://energydata.info/cooking/initiativesandplayersdatabase/about
# 191                                                                                  https://deorbital.media/about
# 192                                                                          https://www.discovernewport.com/about
# 193                                                                                      https://www.mby.com/about
# 194                                                                                 https://elasticemail.com/about
# 195                                                                               https://www.tkaamuseum.org/about
# 196                     https://exhibits.library.jhu.edu/exhibits/show/celebrating-the-philanthropy-o/introduction
# 197                                                                                   https://www.elkost.com/about
# 198                                                                                   https://www.octave.org/about
# 199                                                                                      https://cordeen.com/about
